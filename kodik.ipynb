# %%
import cv2
import numpy as np

# разобратся с возможностью проверки черезмерной насышенности
# разобраться с ошибкой в засветлении 
# добить качество цветовых диапазонов

img1 = cv2.imread('Worst_logo_ever.jpg')
img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2HSV)
image=img1
image1=img1
image2=img1
image3=img1
#red_color1_low = (0,100,60)
#red_color1_high = (10,255,255)
#red_color2_low = (167,50,60)
#red_color2_high = (180,255,255)
#blue_color_low = (90,100,60)
#blue_color_high = (130,255,255)
#green_color_low = (38,100,60)
#green_color_high = (85,255,255)
#yellou_color_low = (26,50,60)
#yellou_color_high = (36,255,255)
#purple_color_low = (130,50,60)
#purple_color_high = (165,255,255)
#orange_color_low = (7,100,110)
#orange_color_high = (18,240,255)
#black_color_low = (0,0,0)
#black_color_high = (180,5,5)
#white_color_low = (0,0,250)
#white_color_high = (180,5,255)
#dark_low = (0, 0, 1)
#dark_high = (180,255, 80)
#light_low = (0, 0, 10)
#light_high = (180,50, 255)
#light_pixel = 0
red_color1_low = (0,100,60)
red_color1_high = (10,255,255)
red1nl = (0,40,60)
red1nh = (10,255,255)
red1ll = (0,100,60)
red1lh = (10,80,255)
red_color2_low = (167,50,60)
red_color2_high = (180,255,255)
red2nl = (0,40,60)
red2nh = (10,255,255)
red2ll = (0,100,60)
red2lh = (10,80,255)
blue_color_low = (89,100,60)
blue_color_high = (130,255,255)
bluenl = (89,40,60)
bluenh = (130,255,255)
bluell = (89,100,60)
bluelh = (130,80,255)
green_color_low = (39,100,60)
green_color_high = (85,255,255)
greennl = (39,40,60)
greennh = (85,255,255)
greenll = (39,100,60)
greenlh = (85,80,255)
yellou_color_low = (26,50,60)
yellou_color_high = (36,255,255)
yellounl = (26,40,60)
yellounh = (36,255,255)
yelloull = (26,50,60)
yelloulh = (36,80,255)
purple_color_low = (130,50,60)
purple_color_high = (165,255,255)
purplenl = (130,40,60)
purplenh = (165,255,255)
purplell = (130,50,60)
purplelh = (165,80,255)
orange_color_low = (7,100,110)
orange_color_high = (18,240,255)
orangenl = (7,40,110)
orangenh = (18,240,255)
orangell = (7,100,110)
orangelh = (18,80,255)
orange_color2_low = (15,100,60)
orange_color2_high = (21,240,255)
black_color_low = (0,0,0)
black_color_high = (180,255,30)
white_color_low = (0,0,250)
white_color_high = (180,5,255)
dark_low = (0, 0, 1)
dark_high = (180,255, 80)
light_low = (0, 40, 20)
light_high = (180,80, 255)
#--------------------------------------------------------------------------
chek = cv2.inRange(img1, red1nl, red1lh)
cv2.imwrite("redlight1_mask.png", chek)
img = cv2.imread('redlight1_mask.png')
boundaries = [ ([255, 255, 255], [255, 255, 255]) ]
for(lower, upper) in boundaries:
    lower = np.array(lower, dtype = "uint8") 
    upper = np.array(upper, dtype = "uint8") 
    mask = cv2.inRange(img, lower, upper) 
    output = cv2.bitwise_and(img, img, mask = mask) 
redlight1_pixel = np.count_nonzero(output)

chek = cv2.inRange(img1, red1ll, red1nh)
cv2.imwrite("reddark_mask1.png", chek)
img = cv2.imread('reddark_mask1.png')
boundaries = [ ([255, 255, 255], [255, 255, 255]) ]
for(lower, upper) in boundaries:
    lower = np.array(lower, dtype = "uint8") 
    upper = np.array(upper, dtype = "uint8") 
    mask = cv2.inRange(img, lower, upper) 
    output = cv2.bitwise_and(img, img, mask = mask) 
reddark1_pixel = np.count_nonzero(output)

chek = cv2.inRange(img1, red2nl, red2lh)
cv2.imwrite("redlight_mask2.png", chek)
img = cv2.imread('redlight_mask2.png')
boundaries = [ ([255, 255, 255], [255, 255, 255]) ]
for(lower, upper) in boundaries:
    lower = np.array(lower, dtype = "uint8") 
    upper = np.array(upper, dtype = "uint8") 
    mask = cv2.inRange(img, lower, upper) 
    output = cv2.bitwise_and(img, img, mask = mask) 
redlight2_pixel = np.count_nonzero(output)

chek = cv2.inRange(img1, red2ll, red2nh)
cv2.imwrite("reddark_mask2.png", chek)
img = cv2.imread('reddark_mask2.png')
boundaries = [ ([255, 255, 255], [255, 255, 255]) ]
for(lower, upper) in boundaries:
    lower = np.array(lower, dtype = "uint8") 
    upper = np.array(upper, dtype = "uint8") 
    mask = cv2.inRange(img, lower, upper) 
    output = cv2.bitwise_and(img, img, mask = mask) 
reddark2_pixel = np.count_nonzero(output)
redlight_pixel=redlight1_pixel+redlight2_pixel
reddark_pixel=reddark1_pixel+reddark2_pixel

chek = cv2.inRange(img1, bluell, bluenh)
cv2.imwrite("bluedark_mask.png", chek)
img = cv2.imread('bluedark_mask.png')
for(lower, upper) in boundaries: 
    lower = np.array(lower, dtype = "uint8") 
    upper = np.array(upper, dtype = "uint8") 
    mask = cv2.inRange(img, lower, upper) 
    output = cv2.bitwise_and(img, img, mask = mask) 
bluedark_pixel = np.count_nonzero(output) 

chek = cv2.inRange(img1, bluenl, bluelh)
cv2.imwrite("bluelight_mask.png", chek)
img = cv2.imread('bluelight_mask.png')
for(lower, upper) in boundaries: 
    lower = np.array(lower, dtype = "uint8") 
    upper = np.array(upper, dtype = "uint8") 
    mask = cv2.inRange(img, lower, upper) 
    output = cv2.bitwise_and(img, img, mask = mask) 
bluelight_pixel = np.count_nonzero(output) 

chek = cv2.inRange(img1, greennl, greenlh)
cv2.imwrite("greenlight_mask.png", chek)
img = cv2.imread('greenlight_mask.png')
for(lower, upper) in boundaries: 
    lower = np.array(lower, dtype = "uint8") 
    upper = np.array(upper, dtype = "uint8") 
    mask = cv2.inRange(img, lower, upper) 
    output = cv2.bitwise_and(img, img, mask = mask) 
greenlight_pixel = np.count_nonzero(output)

chek = cv2.inRange(img1, greenll, greennh)
cv2.imwrite("greendark_mask.png", chek)
img = cv2.imread('greendark_mask.png')
for(lower, upper) in boundaries: 
    lower = np.array(lower, dtype = "uint8") 
    upper = np.array(upper, dtype = "uint8") 
    mask = cv2.inRange(img, lower, upper) 
    output = cv2.bitwise_and(img, img, mask = mask) 
greendark_pixel = np.count_nonzero(output)

chek = cv2.inRange(img1, yellounl, yelloulh)
cv2.imwrite("yelloulight_mask.png", chek)
img = cv2.imread('yelloulight_mask.png')
for(lower, upper) in boundaries: 
    lower = np.array(lower, dtype = "uint8") 
    upper = np.array(upper, dtype = "uint8") 
    mask = cv2.inRange(img, lower, upper) 
    output = cv2.bitwise_and(img, img, mask = mask) 
yellowlight_pixel = np.count_nonzero(output)

chek = cv2.inRange(img1, yelloull, yellounh)
cv2.imwrite("yelloudark_mask.png", chek)
img = cv2.imread('yelloudark_mask.png')
for(lower, upper) in boundaries: 
    lower = np.array(lower, dtype = "uint8") 
    upper = np.array(upper, dtype = "uint8") 
    mask = cv2.inRange(img, lower, upper) 
    output = cv2.bitwise_and(img, img, mask = mask) 
yellowdark_pixel = np.count_nonzero(output)

chek = cv2.inRange(img1, purplenl, purplelh)
cv2.imwrite("purplelight_mask.png", chek)
img = cv2.imread('purplelight_mask.png')
for(lower, upper) in boundaries: 
    lower = np.array(lower, dtype = "uint8") 
    upper = np.array(upper, dtype = "uint8") 
    mask = cv2.inRange(img, lower, upper) 
    output = cv2.bitwise_and(img, img, mask = mask) 
purplelight_pixel = np.count_nonzero(output)

chek = cv2.inRange(img1, purplell, purplenh)
cv2.imwrite("purpledark_mask.png", chek)
img = cv2.imread('purpledark_mask.png')
for(lower, upper) in boundaries: 
    lower = np.array(lower, dtype = "uint8") 
    upper = np.array(upper, dtype = "uint8") 
    mask = cv2.inRange(img, lower, upper) 
    output = cv2.bitwise_and(img, img, mask = mask) 
purpledark_pixel = np.count_nonzero(output)

chek = cv2.inRange(img1, orangenl, orangelh)
cv2.imwrite("orangelight_mask.png", chek)
img = cv2.imread('orangelight_mask.png')
for(lower, upper) in boundaries: 
    lower = np.array(lower, dtype = "uint8") 
    upper = np.array(upper, dtype = "uint8") 
    mask = cv2.inRange(img, lower, upper) 
    output = cv2.bitwise_and(img, img, mask = mask) 
orangelight_pixel = np.count_nonzero(output)

chek = cv2.inRange(img1, orangell, orangenh)
cv2.imwrite("orangedark_mask.png", chek)
img = cv2.imread('orangedark_mask.png')
for(lower, upper) in boundaries: 
    lower = np.array(lower, dtype = "uint8") 
    upper = np.array(upper, dtype = "uint8") 
    mask = cv2.inRange(img, lower, upper) 
    output = cv2.bitwise_and(img, img, mask = mask) 
orangedark_pixel = np.count_nonzero(output)
#--------------------------------------------------------------------------
chek = cv2.inRange(img1, dark_low, dark_high)
cv2.imwrite("dark_mask.png", chek)
img = cv2.imread('dark_mask.png')
boundaries = [ ([255, 255, 255], [255, 255, 255]) ]
for(lower, upper) in boundaries:
    lower = np.array(lower, dtype = "uint8") 
    upper = np.array(upper, dtype = "uint8") 
    mask = cv2.inRange(img, lower, upper) 
    output = cv2.bitwise_and(img, img, mask = mask) 
dark_pixel = np.count_nonzero(output)

chek = cv2.inRange(img1, light_low, light_high)
cv2.imwrite("light_mask.png", chek)
img = cv2.imread('light_mask.png')
boundaries = [ ([255, 255, 255], [255, 255, 255]) ]
for(lower, upper) in boundaries:
    lower = np.array(lower, dtype = "uint8")
    upper = np.array(upper, dtype = "uint8")
    mask = cv2.inRange(img, lower, upper)
    output = cv2.bitwise_and(img, img, mask = mask) 
light_pixel = np.count_nonzero(output)

chek = cv2.inRange(img1, red_color1_low, red_color1_high)
cv2.imwrite("red_mask.png", chek)
img = cv2.imread('red_mask.png')
boundaries = [ ([255, 255, 255], [255, 255, 255]) ]
for(lower, upper) in boundaries:
    lower = np.array(lower, dtype = "uint8") 
    upper = np.array(upper, dtype = "uint8") 
    mask = cv2.inRange(img, lower, upper) 
    output = cv2.bitwise_and(img, img, mask = mask) 
red1_pixel = np.count_nonzero(output)

chek = cv2.inRange(img1, red_color2_low, red_color2_high)
cv2.imwrite("red_mask1.png", chek)
img = cv2.imread('red_mask1.png')
boundaries = [ ([255, 255, 255], [255, 255, 255]) ]
for(lower, upper) in boundaries:
    lower = np.array(lower, dtype = "uint8") 
    upper = np.array(upper, dtype = "uint8") 
    mask = cv2.inRange(img, lower, upper) 
    output = cv2.bitwise_and(img, img, mask = mask) 
red2_pixel = np.count_nonzero(output)
red_pixel=red1_pixel+red2_pixel

chek = cv2.inRange(img1, blue_color_low, blue_color_high)
cv2.imwrite("blue_mask.png", chek)
img = cv2.imread('blue_mask.png')
for(lower, upper) in boundaries: 
    lower = np.array(lower, dtype = "uint8") 
    upper = np.array(upper, dtype = "uint8") 
    mask = cv2.inRange(img, lower, upper) 
    output = cv2.bitwise_and(img, img, mask = mask) 
blue_pixel = np.count_nonzero(output) 

chek = cv2.inRange(img1, green_color_low, green_color_high)
cv2.imwrite("green_mask.png", chek)
img = cv2.imread('green_mask.png')
for(lower, upper) in boundaries: 
    lower = np.array(lower, dtype = "uint8") 
    upper = np.array(upper, dtype = "uint8") 
    mask = cv2.inRange(img, lower, upper) 
    output = cv2.bitwise_and(img, img, mask = mask) 
green_pixel = np.count_nonzero(output)

chek = cv2.inRange(img1, yellou_color_low, yellou_color_high)
cv2.imwrite("yellou_mask.png", chek)
img = cv2.imread('yellou_mask.png')
for(lower, upper) in boundaries: 
    lower = np.array(lower, dtype = "uint8") 
    upper = np.array(upper, dtype = "uint8") 
    mask = cv2.inRange(img, lower, upper) 
    output = cv2.bitwise_and(img, img, mask = mask) 
yellow_pixel = np.count_nonzero(output)

chek = cv2.inRange(img1, purple_color_low, purple_color_high)
cv2.imwrite("purple_mask.png", chek)
img = cv2.imread('purple_mask.png')
for(lower, upper) in boundaries: 
    lower = np.array(lower, dtype = "uint8") 
    upper = np.array(upper, dtype = "uint8") 
    mask = cv2.inRange(img, lower, upper) 
    output = cv2.bitwise_and(img, img, mask = mask) 
purple_pixel = np.count_nonzero(output)

chek = cv2.inRange(img1, orange_color_low, orange_color_high)
cv2.imwrite("orange_mask.png", chek)
img = cv2.imread('orange_mask.png')
for(lower, upper) in boundaries: 
    lower = np.array(lower, dtype = "uint8") 
    upper = np.array(upper, dtype = "uint8") 
    mask = cv2.inRange(img, lower, upper) 
    output = cv2.bitwise_and(img, img, mask = mask) 
orange_pixel = np.count_nonzero(output)

chek = cv2.inRange(img1, black_color_low, black_color_high)
cv2.imwrite("black_mask.png", chek)
img = cv2.imread('black_mask.png')
for(lower, upper) in boundaries: 
    lower = np.array(lower, dtype = "uint8")
    upper = np.array(upper, dtype = "uint8")
    mask = cv2.inRange(img, lower, upper) 
    output = cv2.bitwise_and(img, img, mask = mask)
black_pixel = np.count_nonzero(output)

chek = cv2.inRange(img1, white_color_low, white_color_high)
cv2.imwrite("white_mask.png", chek)
img = cv2.imread('white_mask.png')
for(lower, upper) in boundaries:
    lower = np.array(lower, dtype = "uint8")
    upper = np.array(upper, dtype = "uint8")
    mask = cv2.inRange(img, lower, upper) 
    output = cv2.bitwise_and(img, img, mask = mask) 
white_pixel = np.count_nonzero(output) 

tot_pixel = output.size 

gray = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
gray = cv2.GaussianBlur(gray, (3, 3), 0)
cv2.imwrite("gray.jpg", gray)
edged = cv2.Canny(gray, 10, 250)
cv2.imwrite("edged.jpg", edged)
kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (7, 7))
closed = cv2.morphologyEx(edged, cv2.MORPH_CLOSE, kernel)
cnts0 = cv2.findContours(edged.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)[0]
cv2.imwrite("closed.jpg", closed)
cnts = cv2.findContours(closed.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)[0]
total = 0
total1=0
total2=0
count=0
for c in cnts:
    peri = cv2.arcLength(c, True)
    approx = cv2.approxPolyDP(c, 0.02 * peri, True)
    cv2.drawContours
    count+=1
    if len(approx) == 4:
        cv2.drawContours(image, [approx], -1, (0, 255, 0), 4)
        total += 1
cv2.imwrite("output.jpg", image)
for c in cnts:
    peri = cv2.arcLength(c, True)
    approx = cv2.approxPolyDP(c, 0.02 * peri, True)
    cv2.drawContours
    if len(approx) == 3:
        cv2.drawContours(image1, [approx], -1, (0, 255, 0), 4)
        total1 += 1
for c in cnts:
    peri = cv2.arcLength(c, True)
    approx = cv2.approxPolyDP(c, 0.02 * peri, True)
    cv2.drawContours
    if len(approx) == 5:
        cv2.drawContours(image2, [approx], -1, (0, 255, 0), 4)
        total2 += 1
cv2.imwrite("output1.jpg", image2)

percentage = round(red_pixel * 100 / tot_pixel, 2) 
percentage1 = round(blue_pixel * 100 / tot_pixel, 2) 
percentage2 = round(green_pixel * 100 / tot_pixel, 2) 
percentage3 = round(yellow_pixel * 100 / tot_pixel, 2) 
percentage4 = round(purple_pixel * 100 / tot_pixel, 2) 
percentage5 = round(orange_pixel * 100 / tot_pixel, 2)
percentage6 = round(black_pixel * 100 / tot_pixel, 2) 
percentage7 = round(white_pixel * 100 / tot_pixel, 2)
red=percentage
blue=percentage1
green=percentage2
yellow=percentage3
purple=percentage4
orange=percentage5
black=percentage6
white=percentage7
s=0
v=1
badcnt=0
cnts=len(cnts)
cnts0=len(cnts0)
print("Данные:")
if count>0 or cnts>0 or cnts0>0:
#    print("Contours: " + str(count)) 
#    print("Contours1: " + str(cnts)) 
    print("Сontours: " + str(cnts0))
if count==0 or cnts==0 or cnts0==0:
    badcnt=1
    
print("Trinagle: " + str(total1))
print("Squares: " + str(total))
print("Pentagon: " + str(total2))
print("Dark pixel: " + str(dark_pixel))
print("Light pixel: " + str(light_pixel))
print("Red pixels: " + str(red_pixel)) 
print("Blue pixels: " + str(blue_pixel))
print("Green pixels: " + str(green_pixel)) 
print("Yellow pixels: " + str(yellow_pixel))
print("Purple pixels: " + str(purple_pixel)) 
print("Orange pixels: " + str(orange_pixel))
print("Black pixels: " + str(black_pixel))
print("White pixels: " + str(white_pixel)) 
print("Total pixels: " + str(tot_pixel)) 
print("Percentage of red pixels: " + str(percentage) + "%") 
print("Percentage of blue pixels: " + str(percentage1) + "%") 
print("Percentage of green pixels: " + str(percentage2) + "%") 
print("Percentage of yellow pixels: " + str(percentage3) + "%") 
print("Percentage of purple pixels: " + str(percentage4) + "%") 
print("Percentage of orange pixels: " + str(percentage5) + "%") 
print("Percentage of black pixels: " + str(percentage6) + "%") 
print("Percentage of white pixels: " + str(percentage7) + "%")
if percentage>8:
    s+=1
if percentage1>7:
    s+=1
if percentage2>7:
    s+=1
if percentage3>7:
    s+=1
if percentage4>7:
    s+=1
if percentage5>7:
    s+=1
if percentage6>7:
    s+=1
if percentage7>7:
    s+=1
fn=0
print("Промежуточные выводы:")
if light_pixel>1000:
    print("Присутствует участки с чрезмерным засветлением")
    fn+=1
if dark_pixel>1000:
    print("Присутствует участки с чрезмерным затемнением")
    fn+=1
if total>=1 or total1>=1 or total2>=1:
    print("Есть формы фигур")
    v=1
if cnts0>50:
    print("В существующем дизайне присутствует большое количество деталей")
    fn+=1
if s>5:
    print("Черезмерно много цветов")
    fn+=1
if badcnt==1:
    print("Черезмерно схожая цветовая гамма")
    fn+=1
if blue>0 and green>0:
    fn+=1
    bad=1
    print("Возможное плохое сочетание синего и зелёного")
if white>0 and green>0:
    fn+=1
    bad=1
    print("Возможное плохое сочетание белого и зелёного")
if blue>0 and yellow>0:
    bad=1
    fn+=1
    print("Возможное плохое сочетание синего и жёлтого")
if red>0 and orange>0:
    bad=1
    fn+=1
    print("Возможное плохое сочетание красного и оранжевого")
if black>0 and green>0:
    fn+=1
    bad=1
    print("Возможное плохое сочетание чёрного и зелёного")
if red>0 and green>0:
    bad=1
    fn+=1
    print("Возможное плохое сочетание красного и зелёного")
if red>0 and yellow>0:
    bad=1
    fn+=1
    print("Возможное плохое сочетание красного и жёлтого")
if orangelight_pixel>200 and orangedark_pixel>200:
    print("Плохое сочетание оттенков оранжевого")
    fn+=1
if redlight_pixel>200 and reddark_pixel>200:
    print("Плохое сочетание оттенков красного")
    fn+=1
if bluelight_pixel>200 and bluedark_pixel>200:
    print("Плохое сочетание оттенков синего")
    fn+=1
if greenlight_pixel>200 and greendark_pixel>200:
    fn+=1
    print("Плохое сочетание оттенков зелёного")
if yellowlight_pixel>200 and yellowdark_pixel>200:
    fn+=1
    print("Плохое сочетание оттенков жёлтого")
if purplelight_pixel>200 and purpledark_pixel>200:
    fn+=1
    print("Плохое сочетание оттенков фиолетового")
print("Итоговая оценка:")
#========================================================================================================================
#if (count>20 and ((red>8 and white>8 and s==2) or (green>8 and white>8 and s==2) or (blue>8 and white>8 and s==2) or (black>8 and white>8 and s==2))) or count>20: 
if fn<2:
    print("Excellent attractiveness")
#elif count<20 or (count<20 and ((purple>8 and white>8 and s==2) or (orange>8 and white>8 and s==2) or (yellow>8 and white>8 and (s==2 or s==3)) or (red>8 and white>8 and (s==2 or s==3)) or (green>8 and white>8 and (s==2 or s==3)) or (blue>8 and white>8 and (s==2 or s==3)) or (black>8 and white>8 and (s==2 or s==3)))):
elif fn==2:
    print("Good attractiveness")
#elif count<20 and ((orange>8 and white>8 and s==2) or (yellow>8 and white>8 and s==2)):
elif fn==3:
    print("Medium attractiveness")
#elif count<20 and s>4:
elif fn==4:
    print("Weak attractiveness")
#elif count>20 and s>5:
elif fn>5:
    print("Poor attractiveness")
